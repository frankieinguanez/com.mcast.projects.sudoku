# %% [markdown]
# # Prototype Evaluation
#
# Author: Frankie Inguanez<br/>
# Date: 16/01/2023<br /><br />
#
# An evalation of the revised prototype with improvments.

# %%
import sudokuPuzzleUtils as spu
import solveMultiple as solver

# %%
for s in range(1,9):
    for g in range(1,3):
        config = spu.SudokuConfig(searchMode=s, guessMode=g, tracking=False)

        exec = spu.SudokuExecutor(puzzlesFileName="balanced_24_45_zeros.txt",trackingFileName=None,statsFileName="backtracking_search_{:0.0f}_guess_{:0.0f}.csv".format(s,g), \
                            errorsFileName="backtrackingErrors.txt", offset=0, limit=1100)
        solver.solvePuzzles(exec, config)
# Out:
# Starting sudoku base solver.
# 100%|██████████| 1100/1100 [00:08<00:00, 130.90it/s]
# Sudoku puzzles solved completed successfully.
# Sudoku solver statistics saved in backtracking_search_1_guess_1.csv
# Starting sudoku base solver.
# 100%|██████████| 1100/1100 [00:09<00:00, 120.13it/s]
# Sudoku puzzles solved completed successfully.
# Sudoku solver statistics saved in backtracking_search_1_guess_2.csv
# Starting sudoku base solver.
# 100%|██████████| 1100/1100 [00:08<00:00, 132.26it/s]
# Sudoku puzzles solved completed successfully.
# Sudoku solver statistics saved in backtracking_search_2_guess_1.csv
# Starting sudoku base solver.
# 100%|██████████| 1100/1100 [00:09<00:00, 120.47it/s]
# Sudoku puzzles solved completed successfully.
# Sudoku solver statistics saved in backtracking_search_2_guess_2.csv
# Starting sudoku base solver.
# 100%|██████████| 1100/1100 [05:16<00:00,  3.48it/s]
# Sudoku puzzles solved completed successfully.
# Sudoku solver statistics saved in backtracking_search_3_guess_1.csv
# Starting sudoku base solver.
# 100%|██████████| 1100/1100 [06:50<00:00,  2.68it/s]
# Sudoku puzzles solved completed successfully.
# Sudoku solver statistics saved in backtracking_search_3_guess_2.csv
# Starting sudoku base solver.
# 100%|██████████| 1100/1100 [00:17<00:00, 62.01it/s]
# Sudoku puzzles solved completed successfully.
# Sudoku solver statistics saved in backtracking_search_4_guess_1.csv
# Starting sudoku base solver.
# 100%|██████████| 1100/1100 [00:18<00:00, 60.84it/s]
# Sudoku puzzles solved completed successfully.
# Sudoku solver statistics saved in backtracking_search_4_guess_2.csv
# Starting sudoku base solver.
# 100%|██████████| 1100/1100 [00:17<00:00, 63.01it/s]
# Sudoku puzzles solved completed successfully.
# Sudoku solver statistics saved in backtracking_search_5_guess_1.csv
# Starting sudoku base solver.
# 100%|██████████| 1100/1100 [00:18<00:00, 58.53it/s]
# Sudoku puzzles solved completed successfully.
# Sudoku solver statistics saved in backtracking_search_5_guess_2.csv
# Starting sudoku base solver.
# 100%|██████████| 1100/1100 [00:17<00:00, 63.46it/s]
# Sudoku puzzles solved completed successfully.
# Sudoku solver statistics saved in backtracking_search_6_guess_1.csv
# Starting sudoku base solver.
# 100%|██████████| 1100/1100 [00:18<00:00, 58.96it/s]
# Sudoku puzzles solved completed successfully.
# Sudoku solver statistics saved in backtracking_search_6_guess_2.csv
# Starting sudoku base solver.
# 100%|██████████| 1100/1100 [00:16<00:00, 65.58it/s]
# Sudoku puzzles solved completed successfully.
# Sudoku solver statistics saved in backtracking_search_7_guess_1.csv
# Starting sudoku base solver.
# 100%|██████████| 1100/1100 [00:17<00:00, 62.98it/s]
# Sudoku puzzles solved completed successfully.
# Sudoku solver statistics saved in backtracking_search_7_guess_2.csv
# Starting sudoku base solver.
# 100%|██████████| 1100/1100 [00:47<00:00, 22.95it/s]
# Sudoku puzzles solved completed successfully.
# Sudoku solver statistics saved in backtracking_search_8_guess_1.csv
# Starting sudoku base solver.
# 100%|██████████| 1100/1100 [01:01<00:00, 17.80it/s]
# Sudoku puzzles solved completed successfully.
# Sudoku solver statistics saved in backtracking_search_8_guess_2.csv

# %%
for s in range(9,10):
    for g in range(1,3):
        config = spu.SudokuConfig(searchMode=s, guessMode=g, tracking=False)

        exec = spu.SudokuExecutor(puzzlesFileName="balanced_24_45_zeros.txt",trackingFileName=None,statsFileName="backtracking_search_{:0.0f}_guess_{:0.0f}.csv".format(s,g), \
                            errorsFileName="backtrackingErrors.txt", offset=0, limit=1100)
        solver.solvePuzzles(exec, config)
# Out:
# Starting sudoku base solver.
# 100%|██████████| 1100/1100 [00:22<00:00, 49.65it/s]
# Sudoku puzzles solved completed successfully.
# Sudoku solver statistics saved in backtracking_search_9_guess_1.csv
# Starting sudoku base solver.
# 100%|██████████| 1100/1100 [00:25<00:00, 43.52it/s]
# Sudoku puzzles solved completed successfully.
# Sudoku solver statistics saved in backtracking_search_9_guess_2.csv

# %%
import pandas as pd

stats = pd.DataFrame()

for s in range(1,10):
    for g in range (1,3):
        data = pd.read_csv("backtracking_search_{:0.0f}_guess_{:0.0f}.csv".format(s,g))

        data["algorithm"]="backtracking"
        data["search"]=s
        data["guess"]=g

        if stats.__len__()== 0:
            stats = data
        else:
            stats = pd.concat((stats, data), axis=0)

# %%
toPlot = pd.DataFrame()
toPlot["Zeros"] = stats[(stats["search"]==1)].groupby(by="Zeros").count().index
toPlot["Sequential"] = stats[(stats["search"]==1) & (stats["guess"]==1)].groupby(by="Zeros")["Execution Time"].mean().values
toPlot["Random"] = stats[(stats["search"]==1) & (stats["guess"]==2)].groupby(by="Zeros")["Execution Time"].mean().values
print(toPlot)

ax = toPlot.plot(x="Zeros", y=["Sequential", "Random"], kind="bar", rot=0, figsize=(10,6))
ax.set_ylabel("Mean execution time")
ax.set_title("Backtracking - By Row - Execution Analysis")
# Out:
#     Zeros  Sequential    Random
# 0    24.0    0.006430  0.006372
# 1    25.0    0.006288  0.006349
# 2    26.0    0.006163  0.006361
# 3    27.0    0.006349  0.006833
# 4    28.0    0.006208  0.006441
# 5    29.0    0.006238  0.006618
# 6    30.0    0.006443  0.006597
# 7    31.0    0.006376  0.006606
# 8    32.0    0.006376  0.006619
# 9    33.0    0.006427  0.006665
# 10   34.0    0.006369  0.006817
# 11   35.0    0.006536  0.006916
# 12   36.0    0.006742  0.007142
# 13   37.0    0.006946  0.007620
# 14   38.0    0.006900  0.007177
# 15   39.0    0.007198  0.007959
# 16   40.0    0.007733  0.008866
# 17   41.0    0.007724  0.008695
# 18   42.0    0.008697  0.009394
# 19   43.0    0.009598  0.010299
# 20   44.0    0.012089  0.014548
# 21   45.0    0.014253  0.018293
# Text(0.5, 1.0, 'Backtracking - By Row - Execution Analysis')

# %%
toPlot = pd.DataFrame()
toPlot["Zeros"] = stats[(stats["search"]
].groupby(by="Zeros").count().index
toPlot["Sequential"] = stats[(stats["search"]==9) & (stats["guess"]==1)].groupby(by="Zeros")["Execution Time"].mean().values
toPlot["Random"] = stats[(stats["search"]==9) & (stats["guess"]==2)].groupby(by="Zeros")["Execution Time"].mean().values
print(toPlot)

ax = toPlot.plot(x="Zeros", y=["Sequential", "Random"], kind="bar", rot=0, figsize=(10,6))
ax.set_ylabel("Mean execution time")
ax.set_title("Backtracking - Diagonal by box - Execution Analysis")
# Out:
#     Zeros  Sequential    Random
# 0    24.0    0.013193  0.013111
# 1    25.0    0.013718  0.013715
# 2    26.0    0.012950  0.013168
# 3    27.0    0.013323  0.013087
# 4    28.0    0.013182  0.013268
# 5    29.0    0.013073  0.013350
# 6    30.0    0.013363  0.013642
# 7    31.0    0.013291  0.013973
# 8    32.0    0.013405  0.013686
# 9    33.0    0.013686  0.014060
# 10   34.0    0.013556  0.014180
# 11   35.0    0.013760  0.014513
# 12   36.0    0.014204  0.014676
# 13   37.0    0.014704  0.015071
# 14   38.0    0.016367  0.017392
# 15   39.0    0.016537  0.017149
# 16   40.0    0.017988  0.022812
# 17   41.0    0.024441  0.032492
# 18   42.0    0.025081  0.026185
# 19   43.0    0.033979  0.032790
# 20   44.0    0.061422  0.066312
# 21   45.0    0.050027  0.088911
# Text(0.5, 1.0, 'Backtracking - Diagonal by box - Execution Analysis')

# %%
toPlot = pd.DataFrame()
toPlot["Zeros"] = stats[(stats["search"]==1)].groupby(by="Zeros").count().index
toPlot["Sequential"] = stats[(stats["search"]==1) & (stats["guess"]==1)].groupby(by="Zeros")["Backtracks"].mean().values
toPlot["Random"] = stats[(stats["search"]==1) & (stats["guess"]==2)].groupby(by="Zeros")["Backtracks"].mean().values
print(toPlot)

ax = toPlot.plot(x="Zeros", y=["Sequential", "Random"], kind="bar", rot=0, figsize=(10,6))
ax.set_ylabel("Mean Backtracks")
ax.set_title("Backtracking - By Row - Backtracks Analysis")
# Out:
#     Zeros  Sequential  Random
# 0    24.0        2.06    2.92
# 1    25.0        5.54    3.10
# 2    26.0        3.52    3.58
# 3    27.0        5.22    6.80
# 4    28.0        5.92    5.62
# 5    29.0        6.74    5.46
# 6    30.0       18.64   16.78
# 7    31.0       12.64   14.08
# 8    32.0       13.12   13.60
# 9    33.0       17.72   14.52
# 10   34.0       12.94   22.40
# 11   35.0       20.28   24.86
# 12   36.0       37.12   38.58
# 13   37.0       48.66   57.88
# 14   38.0       48.24   37.48
# 15   39.0       65.16   79.30
# 16   40.0      108.62  120.24
# 17   41.0      103.06  112.74
# 18   42.0      181.42  150.10
# 19   43.0      244.26  186.04
# 20   44.0      435.64  406.54
# 21   45.0      608.90  608.82
# Text(0.5, 1.0, 'Backtracking - By Row - Backtracks Analysis')

# %%
toPlot = pd.DataFrame()
toPlot["Zeros"] = stats[(stats["search"]==2)].groupby(by="Zeros").count().index
toPlot["Sequential"] = stats[(stats["search"]==2) & (stats["guess"]==1)].groupby(by="Zeros")["Backtracks"].mean().values
toPlot["Random"] = stats[(stats["search"]==2) & (stats["guess"]==2)].groupby(by="Zeros")["Backtracks"].mean().values
print(toPlot)

ax = toPlot.plot(x="Zeros", y=["Sequential", "Random"], kind="bar", rot=0, figsize=(10,6))
ax.set_ylabel("Mean Backtracks")
ax.set_title("Backtracking - By column - Backtracks Analysis")
# Out:
#     Zeros  Sequential  Random
# 0    24.0        2.06    2.52
# 1    25.0        5.18    2.48
# 2    26.0        3.52    3.14
# 3    27.0        7.26    5.34
# 4    28.0        6.60    5.92
# 5    29.0        8.46    8.04
# 6    30.0       10.96   10.62
# 7    31.0       12.12   11.10
# 8    32.0       13.22   12.54
# 9    33.0       17.10   18.38
# 10   34.0       18.10   26.52
# 11   35.0       17.30   19.26
# 12   36.0       40.80   26.94
# 13   37.0       37.82   44.68
# 14   38.0       53.66   49.26
# 15   39.0       50.64   68.48
# 16   40.0      127.90   96.74
# 17   41.0      111.86  118.10
# 18   42.0      258.48  288.92
# 19   43.0      320.08  339.90
# 20   44.0      448.90  432.70
# 21   45.0      386.18  384.78
# Text(0.5, 1.0, 'Backtracking - By column - Backtracks Analysis')

# %%
toPlot = pd.DataFrame()
toPlot["Zeros"] = stats[(stats["search"]==3)].groupby(by="Zeros").count().index
toPlot["Sequential"] = stats[(stats["search"]==3) & (stats["guess"]==1)].groupby(by="Zeros")["Backtracks"].mean().values
toPlot["Random"] = stats[(stats["search"]==3) & (stats["guess"]==2)].groupby(by="Zeros")["Backtracks"].mean().values
print(toPlot)

ax = toPlot.plot(x="Zeros", y=["Sequential", "Random"], kind="bar", rot=0, figsize=(10,6))
ax.set_ylabel("Mean Backtracks")
ax.set_title("Backtracking - Random Search - Backtracks Analysis")
# Out:
#     Zeros  Sequential    Random
# 0    24.0       10.10     16.14
# 1    25.0       15.04     11.46
# 2    26.0       12.80     19.48
# 3    27.0       29.06     32.80
# 4    28.0       23.08     23.72
# 5    29.0       44.20     39.22
# 6    30.0       53.94     63.28
# 7    31.0      102.60    106.76
# 8    32.0      116.10    104.32
# 9    33.0      192.88    211.04
# 10   34.0      263.24    277.84
# 11   35.0      234.58    210.20
# 12   36.0      713.12    709.24
# 13   37.0     1139.34    700.78
# 14   38.0     1114.22   1122.12
# 15   39.0     1963.82   2173.54
# 16   40.0     3803.32   4263.06
# 17   41.0     6501.34   8098.82
# 18   42.0    15027.18  13372.70
# 19   43.0    19296.54  45331.78
# 20   44.0    57315.28  55360.90
# 21   45.0   100630.96  89929.72
# Text(0.5, 1.0, 'Backtracking - Random Search - Backtracks Analysis')

# %%
toPlot = pd.DataFrame()
toPlot["Zeros"] = stats[(stats["search"]==4)].groupby(by="Zeros").count().index
toPlot["Sequential"] = stats[(stats["search"]==4) & (stats["guess"]==1)].groupby(by="Zeros")["Backtracks"].mean().values
toPlot["Random"] = stats[(stats["search"]==4) & (stats["guess"]==2)].groupby(by="Zeros")["Backtracks"].mean().values
print(toPlot)

ax = toPlot.plot(x="Zeros", y=["Sequential", "Random"], kind="bar", rot=0, figsize=(10,6))
ax.set_ylabel("Mean Backtracks")
ax.set_title("Backtracking - Sequential by box - Backtracks Analysis")
# Out:
#     Zeros  Sequential  Random
# 0    24.0        2.18    3.28
# 1    25.0        5.54    4.44
# 2    26.0        3.80    2.58
# 3    27.0        5.74    6.10
# 4    28.0        8.18    8.40
# 5    29.0        8.28    9.64
# 6    30.0       21.58   21.42
# 7    31.0       13.82   14.42
# 8    32.0       14.76   12.26
# 9    33.0       18.14   13.28
# 10   34.0       16.44   23.60
# 11   35.0       21.24   24.56
# 12   36.0       39.34   44.18
# 13   37.0       46.22   43.88
# 14   38.0       60.34   56.06
# 15   39.0       67.14   43.90
# 16   40.0      122.98   86.38
# 17   41.0      121.86  136.64
# 18   42.0      186.30  174.06
# 19   43.0      233.32  202.20
# 20   44.0      569.48  421.12
# 21   45.0      554.82  829.48
# Text(0.5, 1.0, 'Backtracking - Sequential by box - Backtracks Analysis')

# %%
toPlot = pd.DataFrame()
toPlot["Zeros"] = stats[(stats["search"]==5)].groupby(by="Zeros").count().index
toPlot["Sequential"] = stats[(stats["search"]==5) & (stats["guess"]==1)].groupby(by="Zeros")["Backtracks"].mean().values
toPlot["Random"] = stats[(stats["search"]==5) & (stats["guess"]==2)].groupby(by="Zeros")["Backtracks"].mean().values
print(toPlot)

ax = toPlot.plot(x="Zeros", y=["Sequential", "Random"], kind="bar", rot=0, figsize=(10,6))
ax.set_ylabel("Mean Backtracks")
ax.set_title("Backtracking - Zig-zag by box - Backtracks Analysis")
# Out:
#     Zeros  Sequential  Random
# 0    24.0        1.86    2.68
# 1    25.0        5.36    3.22
# 2    26.0        4.46    3.98
# 3    27.0        4.94    6.14
# 4    28.0        8.34    9.04
# 5    29.0        7.50    6.46
# 6    30.0       12.44   10.20
# 7    31.0       14.16   13.22
# 8    32.0       14.00   17.78
# 9    33.0       17.56   16.92
# 10   34.0       15.86   25.40
# 11   35.0       23.26   35.88
# 12   36.0       41.74   51.12
# 13   37.0       46.86   44.34
# 14   38.0       60.12   63.54
# 15   39.0       61.32   83.20
# 16   40.0      130.20  100.32
# 17   41.0      123.70   97.28
# 18   42.0      163.64  112.34
# 19   43.0      208.88  217.22
# 20   44.0      435.58  388.98
# 21   45.0      502.26  680.04
# Text(0.5, 1.0, 'Backtracking - Zig-zag by box - Backtracks Analysis')

# %%
toPlot = pd.DataFrame()
toPlot["Zeros"] = stats[(stats["search"]==6)].groupby(by="Zeros").count().index
toPlot["Sequential"] = stats[(stats["search"]==6) & (stats["guess"]==1)].groupby(by="Zeros")["Backtracks"].mean().values
toPlot["Random"] = stats[(stats["search"]==6) & (stats["guess"]==2)].groupby(by="Zeros")["Backtracks"].mean().values
print(toPlot)

ax = toPlot.plot(x="Zeros", y=["Sequential", "Random"], kind="bar", rot=0, figsize=(10,6))
ax.set_ylabel("Mean Backtracks")
ax.set_title("Backtracking - Spiral by box - Backtracks Analysis")
# Out:
#     Zeros  Sequential  Random
# 0    24.0        2.34    2.22
# 1    25.0        5.66    4.06
# 2    26.0        5.12    3.74
# 3    27.0        7.24    6.82
# 4    28.0        8.86    5.90
# 5    29.0        7.30    7.68
# 6    30.0       14.92   11.00
# 7    31.0       17.08   16.28
# 8    32.0       14.18   17.62
# 9    33.0       19.78   17.18
# 10   34.0       21.20   33.02
# 11   35.0       25.26   30.58
# 12   36.0       51.28   75.30
# 13   37.0       61.24   63.70
# 14   38.0       66.20   54.66
# 15   39.0       59.94   75.42
# 16   40.0      147.38  168.38
# 17   41.0      167.02  254.80
# 18   42.0      203.80  183.98
# 19   43.0      285.42  444.02
# 20   44.0      594.08  524.04
# 21   45.0      707.58  578.70
# Text(0.5, 1.0, 'Backtracking - Spiral by box - Backtracks Analysis')

# %%
toPlot = pd.DataFrame()
toPlot["Zeros"] = stats[(stats["search"]==7)].groupby(by="Zeros").count().index
toPlot["Sequential"] = stats[(stats["search"]==7) & (stats["guess"]==1)].groupby(by="Zeros")["Backtracks"].mean().values
toPlot["Random"] = stats[(stats["search"]==7) & (stats["guess"]==2)].groupby(by="Zeros")["Backtracks"].mean().values
print(toPlot)

ax = toPlot.plot(x="Zeros", y=["Sequential", "Random"], kind="bar", rot=0, figsize=(10,6))
ax.set_ylabel("Mean Backtracks")
ax.set_title("Backtracking - Semi-Zig-zag by box - Backtracks Analysis")
# Out:
#     Zeros  Sequential  Random
# 0    24.0        2.04    3.40
# 1    25.0        5.36    3.70
# 2    26.0        3.78    4.58
# 3    27.0        5.34    3.92
# 4    28.0        9.40    8.52
# 5    29.0        8.20    8.18
# 6    30.0       13.62   10.98
# 7    31.0       12.22   12.78
# 8    32.0       12.60   12.34
# 9    33.0       18.64   17.52
# 10   34.0       15.94   17.00
# 11   35.0       19.88   21.70
# 12   36.0       38.34   48.10
# 13   37.0       53.78   58.36
# 14   38.0       94.40   59.04
# 15   39.0       73.84   98.56
# 16   40.0      111.10  128.68
# 17   41.0      133.30  109.64
# 18   42.0      162.08  146.92
# 19   43.0      268.06  292.24
# 20   44.0      413.40  413.66
# 21   45.0      590.06  340.70
# Text(0.5, 1.0, 'Backtracking - Semi-Zig-zag by box - Backtracks Analysis')

# %%
toPlot = pd.DataFrame()
toPlot["Zeros"] = stats[(stats["search"]==8)].groupby(by="Zeros").count().index
toPlot["Sequential"] = stats[(stats["search"]==8) & (stats["guess"]==1)].groupby(by="Zeros")["Backtracks"].mean().values
toPlot["Random"] = stats[(stats["search"]==8) & (stats["guess"]==2)].groupby(by="Zeros")["Backtracks"].mean().values
print(toPlot)

ax = toPlot.plot(x="Zeros", y=["Sequential", "Random"], kind="bar", rot=0, figsize=(10,6))
ax.set_ylabel("Mean Backtracks")
ax.set_title("Backtracking - Random by box - Backtracks Analysis")
# Out:
#     Zeros  Sequential    Random
# 0    24.0        8.18      9.72
# 1    25.0       10.28     11.82
# 2    26.0       15.40     10.32
# 3    27.0       15.58     22.10
# 4    28.0       24.88     21.88
# 5    29.0       23.06     26.02
# 6    30.0       49.86     47.34
# 7    31.0       48.70     56.32
# 8    32.0       65.58     59.18
# 9    33.0       98.12     67.60
# 10   34.0       87.50    111.90
# 11   35.0      104.46     96.62
# 12   36.0      190.20    225.74
# 13   37.0      423.82    376.86
# 14   38.0      258.62    326.92
# 15   39.0      482.10    608.70
# 16   40.0      874.12    900.38
# 17   41.0     1828.22   1923.34
# 18   42.0     2031.80   2333.98
# 19   43.0     3019.36   5431.16
# 20   44.0     6095.56   5047.52
# 21   45.0     9673.40  11811.52
# Text(0.5, 1.0, 'Backtracking - Random by box - Backtracks Analysis')

# %%
toPlot = pd.DataFrame()
toPlot["Zeros"] = stats[(stats["search"]==9)].groupby(by="Zeros").count().index
toPlot["Sequential"] = stats[(stats["search"]==9) & (stats["guess"]==1)].groupby(by="Zeros")["Backtracks"].mean().values
toPlot["Random"] = stats[(stats["search"]==9) & (stats["guess"]==2)].groupby(by="Zeros")["Backtracks"].mean().values
print(toPlot)

ax = toPlot.plot(x="Zeros", y=["Sequential", "Random"], kind="bar", rot=0, figsize=(10,6))
ax.set_ylabel("Mean Backtracks")
ax.set_title("Backtracking - Diagonal by box - Backtracks Analysis")
# Out:
#     Zeros  Sequential   Random
# 0    24.0        2.54     5.48
# 1    25.0        5.02     5.40
# 2    26.0        6.54     6.76
# 3    27.0        7.92     7.70
# 4    28.0       13.38     9.66
# 5    29.0       10.38    11.08
# 6    30.0       21.40    18.58
# 7    31.0       23.66    27.44
# 8    32.0       22.32    22.52
# 9    33.0       32.06    35.80
# 10   34.0       34.50    35.06
# 11   35.0       41.72    53.72
# 12   36.0       75.12    64.44
# 13   37.0       81.96    76.80
# 14   38.0      199.98   178.14
# 15   39.0      199.34   161.88
# 16   40.0      289.16   396.22
# 17   41.0      679.18   772.10
# 18   42.0      698.38   520.62
# 19   43.0     1187.18   792.12
# 20   44.0     2766.10  2128.64
# 21   45.0     2096.60  3011.34
# Text(0.5, 1.0, 'Backtracking - Diagonal by box - Backtracks Analysis')

# %%
aggregatedStats = stats.groupby(by=["algorithm", "search", "guess", "Zeros"])\
    .aggregate({"Execution Time": ["min", "max", "mean","count"], "Guesses": ["min", "max", "mean","count"], "Backtracks": ["min", "max", "mean", "count"]})
aggregatedStats.to_csv("backtracking_analysis.csv")
